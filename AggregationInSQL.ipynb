# %% [markdown]
# ###Question 1: Count how many cities are there in each country.
#
# -->
# ```
# SELECT CountryCode, COUNT(*) AS CityCount
# FROM city
# GROUP BY CountryCode;
# ```
# Link to the result data: https://1drv.ms/x/c/e1a60e1ac5d055b8/IQBLDb651UJPRp0viQOyjHXlAWdnx_bnpsW8JRx2GF6J2mM?e=MpJW20
#
# Explanation:
# This query groups cities by CountryCode and counts the number of cities in each country using COUNT(*).
#
# ---
# ---
#
# ###Question 2: Display all continents having more than 30 countries.
#
# -->
# ```
# SELECT Continent, COUNT(*) AS CountryCount
# FROM country
# GROUP BY Continent
# HAVING COUNT(*) > 30;
# ```
# Link to the result data: https://1drv.ms/x/c/e1a60e1ac5d055b8/IQDp7Q491PwDSIJpa4JCD00yAelDu8d6jIZuZCdnklozMps?e=UoHS6r
#
# Explanation:
# This query groups countries by Continent and filters only those continents where the number of countries exceeds 30.
#
# ---
# ---
#
# ###Question 3: List regions whose total population exceeds 200 million.
#
# -->
# ```
# SELECT Region, SUM(Population) AS TotalPopulation
# FROM country
# GROUP BY Region
# HAVING SUM(Population) > 200000000;
# ```
# Link to the result data: https://1drv.ms/x/c/e1a60e1ac5d055b8/IQBjpFqYEWtQQoy9GFUtLSuvAShI9Y_nJk5dmCqMCa-HU9E?e=qphkMC
#
# Explanation:
# This query calculates the total population per region and returns only regions with population greater than 200 million.
#
# ---
# ---
#
# ###Question 4: Find the top 5 continents by average GNP per country.
#
# -->
# ```
# SELECT Continent, AVG(GNP) AS AvgGNP
# FROM country
# GROUP BY Continent
# ORDER BY AvgGNP DESC
# LIMIT 5;
# ```
# Link to the result data: https://1drv.ms/x/c/e1a60e1ac5d055b8/IQDOba62x1NUQ7iUI2-bKYtUARAPb5kFT0Zd5_CuYDgAP6M?e=MYrraP
#
# Explanation:
# This query computes the average GNP per continent and sorts them from highest to lowest, returning the top 5.
#
# ---
# ---
#
# ###Question 5: Find the total number of official languages spoken in each continent.
#
# -->
# ```
# SELECT country.Continent, COUNT(countrylanguage.Language) AS OfficialLanguageCount
# FROM country
# JOIN countrylanguage
# ON country.Code = countrylanguage.CountryCode
# WHERE countrylanguage.IsOfficial = 'T'
# GROUP BY country.Continent;
# ```
# Link to the result data: https://1drv.ms/x/c/e1a60e1ac5d055b8/IQBBXC31lz8NQ7EC099aN3PsAT8QOq6VvHmjU-qEJa1P5pE?e=kQSQTJ
#
# Explanation:
# This query joins country and countrylanguage tables, filters official languages, and counts them per continent.
#
# ---
# ---
#
# ###Question 6: Find the maximum and minimum GNP for each continent.
#
# -->
# ```
# SELECT Continent,
#        MAX(GNP) AS MaximumGNP,
#        MIN(GNP) AS MinimumGNP
# FROM country
# GROUP BY Continent;
# ```
# Link to the result data: https://1drv.ms/x/c/e1a60e1ac5d055b8/IQAOuXTObcDUQont3_ptrOWwARus8RCOBcUDZ5qLlK_5P-g?e=xvD7Qn
#
# Explanation:
# This query finds the highest and lowest GNP values within each continent.
#
# ---
# ---
#
# ###Question 7: Find the country with the highest average city population.
#
# -->
# ```
# SELECT country.Name, AVG(city.Population) AS AvgCityPopulation
# FROM country
# JOIN city ON country.Code = city.CountryCode
# GROUP BY country.Name
# ORDER BY AvgCityPopulation DESC
# LIMIT 1;
# ```
# Link to the result data: https://1drv.ms/x/c/e1a60e1ac5d055b8/IQBXxtS40SorTqeSdHKHguxyAaEj1WEQGHYo-JU9s7Qojb8?e=ZQFUSQ
#
# Explanation:
# This query calculates average city population per country and returns the country with the highest value.
#
# ---
# ---
#
# ###Question 8: List continents where the average city population is greater than 200,000.
#
# -->
# ```
# SELECT country.Continent, AVG(city.Population) AS AvgCityPopulation
# FROM country
# JOIN city ON country.Code = city.CountryCode
# GROUP BY country.Continent
# HAVING AVG(city.Population) > 200000;
# ```
# Link to the result data: https://1drv.ms/x/c/e1a60e1ac5d055b8/IQAljVxU-8amQLTTWrHJemIFAe8KdSQk9kN4gcelvWSiuuQ?e=TCbbsP
#
# Explanation:
# This query computes average city population per continent and filters continents above 200,000.
#
# ---
# ---
#
# ###Question 9: Find the total population and average life expectancy for each continent.
#
# -->
# ```
# SELECT Continent,
#        SUM(Population) AS TotalPopulation,
#        AVG(LifeExpectancy) AS AvgLifeExpectancy
# FROM country
# GROUP BY Continent
# ORDER BY AvgLifeExpectancy DESC;
# ```
# Link to the result data: https://1drv.ms/x/c/e1a60e1ac5d055b8/IQDyzTqHg-qlSprF9FGK2JmUAaJy6WwZdtzt-MqnhfhLUYc?e=dYMICF
#
# Explanation:
# This query calculates total population and average life expectancy per continent and sorts by life expectancy.
#
# ---
# ---
#
# ###Question 10: Find the top 3 continents with the highest average life expectancy, where total population is over 200 million.
#
# -->
#
# ```
# SELECT Continent,
#        AVG(LifeExpectancy) AS AvgLifeExpectancy,
#        SUM(Population) AS TotalPopulation
# FROM country
# GROUP BY Continent
# HAVING SUM(Population) > 200000000
# ORDER BY AvgLifeExpectancy DESC
# LIMIT 3;
# ```
# Link to the result data: https://1drv.ms/x/c/e1a60e1ac5d055b8/IQBJEPPMgwU3Q65P1Btd-soBAf9ebtLqJQqabD-eEF1audE?e=GzeOb4
#
# Explanation:
# This query filters continents by population threshold and returns the top 3 based on average life expectancy.
#
# ---
# ---
