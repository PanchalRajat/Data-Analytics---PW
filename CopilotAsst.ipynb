# %% [markdown]
# ### 1. Use Copilot to identify and summarize missing values in the dataset
# Answer:
#
# --> Missing values are present in multiple columns of the dataset.
#
# --> Region column:
# Some records have no region mentioned (blank values).
#
# --> Category column:
# Several rows have missing product categories.
#
# --> Units Sold column:
# A few orders do not have values for units sold.
#
# --> Unit Price column:
# Some rows have missing unit price values.
#
# --> Other columns:
# Country, Sales Channel, Order Priority, Order Date, and Unit Cost are mostly complete with no significant missing values observed.
#
# Summary:
#
# --> The dataset contains incomplete data, mainly in Region, Category, Units Sold, and Unit Price columns.
# --> These missing values should be handled (removed or filled) before performing accurate sales, revenue, or profit analysis.
#
# link to the data: https://1drv.ms/x/c/e1a60e1ac5d055b8/IQDSShVKyY3bRonjNHNJ2rEQARFcbpD2MVcAAnfqFNJzZsM?e=D5RQrk
#
# ---
# ---
# ### Q2. Use Copilot to fill missing values in the Region and Category columns
# Answer:
#
# --> Missing values in the Region column were filled using the most frequently occurring region for similar records.
#
# --> Missing values in the Category column were filled using the most frequently occurring product category.
#
# --> After filling, there are no missing values in the Region and Category columns.
# Link to the updated data: https://1drv.ms/x/c/e1a60e1ac5d055b8/IQAF2_2opgmIRIiNvxlphMyMASO2OszUMI_mim_kaP7KCUU?e=yV25Xm
#
# ---
# ---
# ### Q3. Fill missing numeric values in the Units Sold and Unit Price columns
# Answer:
#
# --> All the coumns are now filled by the copilot here is the link to the data
# https://1drv.ms/x/c/e1a60e1ac5d055b8/IQAF2_2opgmIRIiNvxlphMyMASO2OszUMI_mim_kaP7KCUU?e=yV25Xm
#
# ---
# ---
#
# ### Q4. Create a new calculated column Total Revenue
# Answer:
#
# --> dataset now includes a new calculated column called Total Revenue, which is simply Units Sold × Unit Price.
# link to the data: https://1drv.ms/x/c/e1a60e1ac5d055b8/IQC6H8ZxWdHPQ4l_D0G3KG1AAbXk11VBjofoJMfom-jjLq4?e=hlGEBJ
#
# ---
# ---
# ### Q5. Use Copilot to find the total price of Order ID = ‘ORD0123’.
# Answer:
#
# -->For Order ID = ORD0123, here are the details:
#
# Region: South
#
# Country: Germany
#
# Category: Clothing
#
# Sales Channel: Online
#
# Order Priority: Low
#
# Units Sold: 46
#
# Unit Price: 344.55
#
# Unit Cost: 377.25
#
# Total Revenue: 15,849.30
#
# So, the total price (Total Revenue) for this order is 15,849.30.
#
# ---
# ---
#
# ### Q6.  Use Copilot to generate a summary chart of average profit by region.
#
# Answer:
#
# --> here is summary made by copilot  and some edited by to make it look more good
# link to the data: https://1drv.ms/x/c/e1a60e1ac5d055b8/IQBdtQ93x4VUSZbIxMcK9WUTAUCVFpjILYOP7SpW0aCDF2c?e=fmHJED
# ---
# ---
# ### Q7. Create a pivot table summarizing total sales by category and region.
# Answer:
#
# --> pivot table showing toal sales by category and region
# link to the data: https://1drv.ms/x/c/e1a60e1ac5d055b8/IQAqT8ZJGWMERpgcwZUDsa-qARi8Hk2oONTAxwHnjsTVMF0?e=4UV5EI
#
# ---
# ---
#
# ### Q9. Use Copilot to generate a summary report.
# Answer:
# Link to the report which was made using copilot:
# https://drive.google.com/file/d/1kRyPX6FzSe4wO__iRfREUXhZ2my7ocy5/view?usp=drive_link
# -->
# ---
# ---
